# %% [markdown]
# # Working with the measuremnt execution engine

# %% [markdown]
# ## Don't fear plans: they are just structured input

# %% [markdown]
# ## A simple plan: set something read something

# %% [markdown]
# ## Put together: run chromaticity
